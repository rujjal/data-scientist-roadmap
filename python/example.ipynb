# %%
print("welcome to the world of Python programming!  Enjoy your coding journey.  ")

n = int(input("Enter a number: ")  )
if n % 2 == 0:
    print(f"{n} is an even number.")
else:
    print(f"{n} is an odd number.")
# Out:
# welcome to the world of Python programming!  Enjoy your coding journey.
# 10 is an even number.
